# %%
d={"Name":["Ankit","Arun","Anjali"],"Age":[19,20,21],"Roll no.":[1,2,3]} #defining dictionaries
d
# Out:
# {'Name': ['Ankit', 'Arun', 'Anjali'],
#  'Age': [19, 20, 21],
#  'Roll no.': [1, 2, 3]}

# %%
type(d)
# Out:
# dict

# %%
d.keys()
# Out:
# dict_keys(['Name', 'Age', 'Roll no.'])

# %%
d.values()
# Out:
# dict_values([['Ankit', 'Arun', 'Anjali'], [19, 20, 21], [1, 2, 3]])

# %%
d["Name"]
# Out:
# ['Ankit', 'Arun', 'Anjali']

# %%
d["Roll no."]
# Out:
# [1, 2, 3]

# %%
#pandas(Python Data Analysis library) is used for data analysis
#pd is shortform to specify pandas if not so everytime you have to write pandas.something()
import pandas as pd

# %%
a=[11,12,13,14]
a
# Out:
# [11, 12, 13, 14]

# %%
type(a)
# Out:
# list

# %%
s=pd.Series(a,index=["a","b","c","d"])  #gives index to all list elements

# %%
s
# Out:
# a    11
# b    12
# c    13
# d    14
# dtype: int64

# %%
s.ndim
# Out:
# 1

# %%
s.index #shows the index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
s.values #shows the values
# Out:
# array([11, 12, 13, 14], dtype=int64)

# %%
x=s.values
type(x)
# Out:
# numpy.ndarray

# %%
type(s)   #shows series
# Out:
# pandas.core.series.Series

# %%
d
# Out:
# {'Name': ['Ankit', 'Arun', 'Anjali'],
#  'Age': [19, 20, 21],
#  'Roll no.': [1, 2, 3]}

# %%
df=pd.DataFrame(d)  #making dataframe from dictionary
print(type(d))
print(df)
# Out:
# <class 'dict'>
#      Name  Age  Roll no.
# 0   Ankit   19         1
# 1    Arun   20         2
# 2  Anjali   21         3

# %%
type(df)  #dataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
df    #shows same as above in print(df)
# Out:
#      Name  Age  Roll no.
# 0   Ankit   19         1
# 1    Arun   20         2
# 2  Anjali   21         3

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Roll no.'], dtype='object')

# %%
df.index  #shows the range of dataFrame
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df["Roll no."]  #is used to print particulars
# Out:
# 0    1
# 1    2
# 2    3
# Name: Roll no., dtype: int64

# %%
#It's time for data analysis by importing the file in python
import pandas as pd

# %%
mydata=pd.read_csv(r"E:\BOOKS pdf\EXTRA STUFFS\Internships\DataSets-master\imdrating.csv")

# %%
mydata  #after importing csv file from harddisk
# Out:
#      Unnamed: 0  star_rating  \
# 0             0          9.3
# 1             1          9.2
# 2             2          9.1
# 3             3          9.0
# 4             4          8.9
# 5             5          8.9
# 6             6          8.9
# 7             7          8.9
# 8             8          8.9
# 9             9          8.9
# 10           10          8.8
# 11           11          8.8
# 12           12          8.8
# 13           13          8.8
# 14           14          8.8
# 15           15          8.7
# 16           16          8.7
# 17           17          8.7
# 18           18          8.7
# 19           19          8.7
# 20           20          8.7
# 21           21          8.7
# 22           22          8.7
# 23           23          8.7
# 24           24          8.7
# 25           25          8.6
# 26           26          8.6
# 27           27          8.6
# 28           28          8.6
# 29           29          8.6
# ..          ...          ...
# ...

# %%
type(mydata)
# Out:
# pandas.core.frame.DataFrame

# %%
len(mydata)
# Out:
# 979

# %%
mydata.shape
# Out:
# (979, 7)

# %%
mydata.head(1) #shows only one data from head
# Out:
#    Unnamed: 0  star_rating                     title content_rating  genre  \
# 0           0          9.3  The Shawshank Redemption              R  Crime
#
#    duration                                        actors_list
# 0       142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...

# %%
mydata.head(4) #shows 4 data from head
# Out:
#    Unnamed: 0  star_rating                     title content_rating   genre  \
# 0           0          9.3  The Shawshank Redemption              R   Crime
# 1           1          9.2             The Godfather              R   Crime
# 2           2          9.1    The Godfather: Part II              R   Crime
# 3           3          9.0           The Dark Knight          PG-13  Action
#
#    duration                                        actors_list
# 0       142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1       175    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3       152  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
mydata.size
# Out:
# 6853

# %%
mydata.head() #default shows top 5
# Out:
#    Unnamed: 0  star_rating                     title content_rating   genre  \
# 0           0          9.3  The Shawshank Redemption              R   Crime
# 1           1          9.2             The Godfather              R   Crime
# 2           2          9.1    The Godfather: Part II              R   Crime
# 3           3          9.0           The Dark Knight          PG-13  Action
# 4           4          8.9              Pulp Fiction              R   Crime
#
#    duration                                        actors_list
# 0       142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1       175    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3       152  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4       154  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
mydata.keys() #shows all keys of dataFrame
# Out:
# Index(['Unnamed: 0', 'star_rating', 'title', 'content_rating', 'genre',
#        'duration', 'actors_list'],
#       dtype='object')

# %%
mydata.columns
# Out:
# Index(['Unnamed: 0', 'star_rating', 'title', 'content_rating', 'genre',
#        'duration', 'actors_list'],
#       dtype='object')

# %%
mynewdata=mydata.drop(['Unnamed: 0'],axis=1) #this will drop the Unnamed column axis=1

# %%
mynewdata
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
t=mynewdata["title"] #t is now a series (index+list)
type(t)
# Out:
# pandas.core.series.Series

# %%
t
# Out:
# 0                               The Shawshank Redemption
# 1                                          The Godfather
# 2                                 The Godfather: Part II
# 3                                        The Dark Knight
# 4                                           Pulp Fiction
# 5                                           12 Angry Men
# 6                         The Good, the Bad and the Ugly
# 7          The Lord of the Rings: The Return of the King
# 8                                       Schindler's List
# 9                                             Fight Club
# 10     The Lord of the Rings: The Fellowship of the Ring
# 11                                             Inception
# 12        Star Wars: Episode V - The Empire Strikes Back
# 13                                          Forrest Gump
# 14                 The Lord of the Rings: The Two Towers
# 15                                          Interstellar
# ...

# %%
tt=t.values #used to show values
print(tt)
# Out:
# ['The Shawshank Redemption' 'The Godfather' 'The Godfather: Part II'
#  'The Dark Knight' 'Pulp Fiction' '12 Angry Men'
#  'The Good, the Bad and the Ugly'
#  'The Lord of the Rings: The Return of the King' "Schindler's List"
#  'Fight Club' 'The Lord of the Rings: The Fellowship of the Ring'
#  'Inception' 'Star Wars: Episode V - The Empire Strikes Back'
#  'Forrest Gump' 'The Lord of the Rings: The Two Towers' 'Interstellar'
#  "One Flew Over the Cuckoo's Nest" 'Seven Samurai' 'Goodfellas'
#  'Star Wars' 'The Matrix' 'City of God' "It's a Wonderful Life"
#  'The Usual Suspects' 'Se7en' 'Life Is Beautiful'
#  'Once Upon a Time in the West' 'The Silence of the Lambs'
#  'Leon: The Professional' 'City Lights' 'Spirited Away' 'The Intouchables'
#  'Casablanca' 'Whiplash' 'American History X' 'Modern Times'
#  'Saving Private Ryan' 'Raiders of the Lost Ark' 'Rear Window' 'Psycho'
#  'The Green Mile' 'Sunset Blvd.' 'The Pianist' 'The Dark Knight Rises'
# ...

# %%
print(type(tt)) #tt only contains values so ndarray
# Out:
# <class 'numpy.ndarray'>

# %%
ta=list(tt) #ta is list now
type(ta)
# Out:
# list

# %%
ta #ta is list
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'The Godfather: Part II',
#  'The Dark Knight',
#  'Pulp Fiction',
#  '12 Angry Men',
#  'The Good, the Bad and the Ugly',
#  'The Lord of the Rings: The Return of the King',
#  "Schindler's List",
#  'Fight Club',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Inception',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  'Forrest Gump',
#  'The Lord of the Rings: The Two Towers',
#  'Interstellar',
#  "One Flew Over the Cuckoo's Nest",
#  'Seven Samurai',
#  'Goodfellas',
#  'Star Wars',
#  'The Matrix',
#  'City of God',
#  "It's a Wonderful Life",
#  'The Usual Suspects',
#  'Se7en',
#  'Life Is Beautiful',
#  'Once Upon a Time in the West',
#  'The Silence of the Lambs',
#  'Leon: The Professional',
#  'City Lights',
#  'Spirited Away',
#  'The Intouchables',
#  'Casablanca',
#  'Whiplash',
#  'American History X',
#  'Modern Times',
#  'Saving Private Ryan',
#  'Raiders of the Lost Ark',
#  'Rear Window',
# ...

# %%
t=mynewdata[["title","duration"]]
type(t)
# Out:
# pandas.core.frame.DataFrame

# %%
t
# Out:
#                                                  title  duration
# 0                             The Shawshank Redemption       142
# 1                                        The Godfather       175
# 2                               The Godfather: Part II       200
# 3                                      The Dark Knight       152
# 4                                         Pulp Fiction       154
# 5                                         12 Angry Men        96
# 6                       The Good, the Bad and the Ugly       161
# 7        The Lord of the Rings: The Return of the King       201
# 8                                     Schindler's List       195
# 9                                           Fight Club       139
# 10   The Lord of the Rings: The Fellowship of the Ring       178
# 11                                           Inception       148
# 12      Star Wars: Episode V - The Empire Strikes Back       124
# ...

# %%
mynewdata.head(2) #top 2 elements
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']

# %%
mynewdata.iloc[0,:] #0th row and columns
# Out:
# star_rating                                                     9.3
# title                                      The Shawshank Redemption
# content_rating                                                    R
# genre                                                         Crime
# duration                                                        142
# actors_list       [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# Name: 0, dtype: object

# %%
mynewdata.index
# Out:
# RangeIndex(start=0, stop=979, step=1)

# %%
mynewdata.iloc[0,2:4] #does not take 0-(end values) in columns count
# Out:
# content_rating        R
# genre             Crime
# Name: 0, dtype: object

# %%
mynewdata.iloc[0:12:2,2:4] #0 to (12-1) stepSize 2 and 2 to (4-1) in columns
# Out:
#    content_rating      genre
# 0               R      Crime
# 2               R      Crime
# 4               R      Crime
# 6       NOT RATED    Western
# 8               R  Biography
# 10          PG-13  Adventure

# %%
mynewdata.loc[0:12:2,["title","genre"]] #loc is used for string location here in columns
# Out:
#                                                 title      genre
# 0                            The Shawshank Redemption      Crime
# 2                              The Godfather: Part II      Crime
# 4                                        Pulp Fiction      Crime
# 6                      The Good, the Bad and the Ugly    Western
# 8                                    Schindler's List  Biography
# 10  The Lord of the Rings: The Fellowship of the Ring  Adventure
# 12     Star Wars: Episode V - The Empire Strikes Back     Action

# %%
mynewdata["genre"]=="Crime" #checks the condition is true or false
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23      True
# 24     False
# 25     False
# 26     False
# 27     False
# 28      True
# 29     False
#        ...
# 949    False
# 950     True
# 951    False
# 952    False
# 953    False
# 954    False
# 955    False
# 956    False
# 957    False
# 958    False
# 959    False
# 960    False
# 961    False
# 962    False
# 963    False
# 964    False
# 965    False
# 966    False
# 967    False
# 968    False
# 969     True
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# 977    False
# 978     True
# Name: genre, Length: 979, dtype: bool

# %%
xcrime=mydata[mynewdata["genre"]=="Crime"] #this will prints only those rows where condition is true(genre is Crime)

# %%
xcrime.shape
# Out:
# (124, 7)

# %%
xcrime
# Out:
#      Unnamed: 0  star_rating                             title content_rating  \
# 0             0          9.3          The Shawshank Redemption              R
# 1             1          9.2                     The Godfather              R
# 2             2          9.1            The Godfather: Part II              R
# 4             4          8.9                      Pulp Fiction              R
# 21           21          8.7                       City of God              R
# 23           23          8.7                The Usual Suspects              R
# 28           28          8.6            Leon: The Professional              R
# 34           34          8.6                American History X              R
# 40           40          8.5                    The Green Mile              R
# 49           49          8.5                      The Departed              R
# 63           63          8.4                                 M      NOT RATED
# ...

# %%
xcrime_142=xcrime[xcrime["duration"]>142] #genre crime duration>142
len(xcrime_142)
# Out:
# 23

# %%
xcrime_142
# Out:
#      Unnamed: 0  star_rating                             title content_rating  \
# 1             1          9.2                     The Godfather              R
# 2             2          9.1            The Godfather: Part II              R
# 4             4          8.9                      Pulp Fiction              R
# 40           40          8.5                    The Green Mile              R
# 49           49          8.5                      The Departed              R
# 78           78          8.4       Once Upon a Time in America              R
# 115         115          8.3                          Scarface              R
# 257         257          8.1               Anatomy of a Murder        UNRATED
# 290         290          8.1                         Prisoners              R
# 300         300          8.0                          Dogville              R
# 426         426          7.9                         A Prophet              R
# ...

# %%
p=mynewdata["star_rating"].sum(axis=0)/len(mynewdata) #average rating

# %%
p
# Out:
# 7.889785495403474

# %%
import numpy as np

# %%
mynewdata.describe().T  #describe shows the stastical data
# Out:
#              count        mean        std   min    25%    50%    75%    max
# star_rating  979.0    7.889785   0.336069   7.4    7.6    7.8    8.1    9.3
# duration     979.0  120.979571  26.218010  64.0  102.0  117.0  134.0  242.0

# %%
mynewdata.describe(include=np.number,percentiles=[.01,.02,.50]).T #take percentage according to your ease
# Out:
#              count        mean        std   min     1%     2%    50%    max
# star_rating  979.0    7.889785   0.336069   7.4   7.40   7.40    7.8    9.3
# duration     979.0  120.979571  26.218010  64.0  77.56  80.56  117.0  242.0

# %%
mynewdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
# star_rating       979 non-null float64
# title             979 non-null object
# content_rating    976 non-null object
# genre             979 non-null object
# duration          979 non-null int64
# actors_list       979 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
mydata.info() #more memory consumes Unnamed included
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 7 columns):
# Unnamed: 0        979 non-null int64
# star_rating       979 non-null float64
# title             979 non-null object
# content_rating    976 non-null object
# genre             979 non-null object
# duration          979 non-null int64
# actors_list       979 non-null object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 53.6+ KB

# %%
mynewdata.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
mydata.dtypes
# Out:
# Unnamed: 0          int64
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object
