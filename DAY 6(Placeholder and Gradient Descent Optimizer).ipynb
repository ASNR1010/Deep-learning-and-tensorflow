# %%
import numpy as np
import tensorflow as tf

# %%
#None defines shape if [2,None] and [2,2] than you fix both we use None for dynamic
x=tf.placeholder('float',None)
y=x+10                            #here you can also use tf.add(x)+10 also

# %%
print(x)
print(y)
# Out:
# Tensor("Placeholder:0", dtype=float32)
# Tensor("add:0", dtype=float32)

# %%
with tf.Session() as sess:    #fill methods is known as feed
    re=sess.run(y,feed_dict={x:5})
    print(re)
sess.close()
# Out:
# 15.0

# %%
with tf.Session() as sess:      #fill as many values you want
         re=sess.run(y,feed_dict={x:[5,4,4,4]})  
         print(re)
sess.close()
# Out:
# [15. 14. 14. 14.]

# %%
#variable ki value we cannot fill by Session
x=tf.placeholder(tf.float32,[None,1])
w=tf.Variable(tf.zeros([1,1]))
b=tf.Variable(tf.zeros([1]))
product=tf.matmul(x,w)
Yp=tf.add(product,b)
Ya=tf.placeholder(tf.float32,[None,1])              #question as x answer always 1
cost_f=tf.reduce_mean(tf.square(Ya-Yp))             #cost function reduce by gradient descend 
init=tf.global_variables_initializer()              #this method initialize the variable
training_step=tf.train.GradientDescentOptimizer(.001).minimize(cost_f)

# %%
with tf.Session() as sess:
    sess.run(init)
    steps=100
    for i in range(steps):
        Xs=np.array([[i]])
        Ys=np.array([[2*i]])
        feed={x:Xs,Ya:Ys}
        sess.run(training_step,feed_dict=feed)
        print("After {} iteration :".format(i))
        print("w : %f"% sess.run(w))
        print("b :%f"% sess.run(b))
        print("cost :%f"% sess.run(cost_f,feed_dict=feed))
# Out:
# After 0 iteration :
# w : 0.000000
# b :0.000000
# cost :0.000000
# After 1 iteration :
# w : 0.004000
# b :0.004000
# cost :3.968064
# After 2 iteration :
# w : 0.019952
# b :0.011976
# cost :15.587652
# After 3 iteration :
# w : 0.055521
# b :0.023832
# cost :33.751507
# After 4 iteration :
# w : 0.117554
# b :0.039341
# cost :56.106762
# After 5 iteration :
# w : 0.211283
# b :0.058086
# cost :78.952126
# After 6 iteration :
# w : 0.339373
# b :0.079435
# cost :97.699898
# After 7 iteration :
# w : 0.501003
# b :0.102525
# cost :107.961601
# After 8 iteration :
# w : 0.691234
# b :0.126304
# cost :106.994720
# After 9 iteration :
# w : 0.900981
# b :0.149609
# cost :94.898125
# After 10 iteration :
# w : 1.117792
# b :0.171290
# cost :74.836136
# After 11 iteration :
# w : 1.327518
# b :0.190356
# cost :51.940033
# After 12 iteration :
# w : 1.516624
# b :0.206115
# cost :31.297230
# After 13 iteration :
# w : 1.674646
# b :0.218270
# cost :16.090750
# After 14 iteration :
# w : 1.796073
# b :0.226944
# cost :6.906536
# After 15 iteration :
# w : 1.881032
# b :0.232608
# cost :2.408432
# After 16 iteration :
# w : 1.934500
# b :0.235949
# cost :0.659422
# After 17 iteration :
# w : 1.964337
# b :0.237704
# cost :0.135843
# After 18 iteration :
# w : 1.978889
# b :0.238513
# cost :0.020018
# After 19 iteration :
# w : 1.985068
# b :0.238838
# cost :0.002014
# After 20 iteration :
# w : 1.987460
# b :0.238958
# cost :0.000140
# After 21 iteration :
# w : 1.988484
# b :0.239006
# cost :0.000008
# After 22 iteration :
# w : 1.989115
# b :0.239035
# cost :0.000000
# After 23 iteration :
# w : 1.989636
# b :0.239058
# cost :0.000000
# After 24 iteration :
# w : 1.990100
# b :0.239077
# cost :0.000002
# After 25 iteration :
# w : 1.990521
# b :0.239094
# cost :0.000004
# After 26 iteration :
# w : 1.990904
# b :0.239109
# cost :0.000007
# After 27 iteration :
# w : 1.991254
# b :0.239122
# cost :0.000009
# After 28 iteration :
# w : 1.991577
# b :0.239133
# cost :0.000011
# After 29 iteration :
# w : 1.991875
# b :0.239143
# cost :0.000012
# After 30 iteration :
# w : 1.992151
# b :0.239153
# cost :0.000014
# After 31 iteration :
# w : 1.992409
# b :0.239161
# cost :0.000015
# After 32 iteration :
# w : 1.992649
# b :0.239168
# cost :0.000015
# After 33 iteration :
# w : 1.992875
# b :0.239175
# cost :0.000016
# After 34 iteration :
# w : 1.993084
# b :0.239181
# cost :0.000016
# After 35 iteration :
# w : 1.993285
# b :0.239187
# cost :0.000017
# After 36 iteration :
# w : 1.993468
# b :0.239192
# cost :0.000016
# After 37 iteration :
# w : 1.993653
# b :0.239197
# cost :0.000019
# After 38 iteration :
# w : 1.993804
# b :0.239201
# cost :0.000014
# After 39 iteration :
# w : 1.993994
# b :0.239206
# cost :0.000025
# After 40 iteration :
# w : 1.994078
# b :0.239208
# cost :0.000005
# After 41 iteration :
# w : 1.994373
# b :0.239215
# cost :0.000072
# After 42 iteration :
# w : 1.994131
# b :0.239210
# cost :0.000053
# After 43 iteration :
# w : 1.995263
# b :0.239236
# cost :0.001262
# After 44 iteration :
# w : 1.992553
# b :0.239174
# cost :0.007832
# After 45 iteration :
# w : 2.001188
# b :0.239366
# cost :0.085746
# After 46 iteration :
# w : 1.974139
# b :0.238778
# cost :0.904104
# After 47 iteration :
# w : 2.065948
# b :0.240732
# cost :11.157665
# After 48 iteration :
# w : 1.738948
# b :0.233919
# cost :151.206192
# After 49 iteration :
# w : 2.969596
# b :0.259034
# cost :2281.901855
# After 50 iteration :
# w : -1.904289
# b :0.161557
# cost :38045.628906
# After 51 iteration :
# w : 18.389343
# b :0.559471
# cost :699591.625000
# After 52 iteration :
# w : -70.302414
# b :-1.146140
# cost :14144157.000000
# After 53 iteration :
# w : 336.014038
# b :6.520209
# cost :313618016.000000
# After 54 iteration :
# w : -1612.660034
# b :-29.566347
# cost :7607538176.000000
# After 55 iteration :
# w : 8159.285156
# b :148.105392
# cost :201420341248.000000
# After 56 iteration :
# w : -43019.796875
# b :-765.806763
# cost :5808033628160.000000
# After 57 iteration :
# w : 236623.171875
# b :4140.209961
# cost :182021838077952.000000
# After 58 iteration :
# w : -1355844.375000
# b :-23316.128906
# cost :6187775489474560.000000
# After 59 iteration :
# w : 8086310.500000
# b :136720.390625
# cost :227747444098596864.000000
# After 60 iteration :
# w : -50151520.000000
# b :-833910.125000
# cost :9059647608653348864.000000
# After 61 iteration :
# w : 323177824.000000
# b :5286243.500000
# cost :388844204711261241344.000000
# After 62 iteration :
# w : -2162069248.000000
# b :-34798380.000000
# cost :17978275136870845251584.000000
# After 63 iteration :
# w : 15004822528.000000
# b :237691952.000000
# cost :894048833418067831685120.000000
# After 64 iteration :
# w : -107945115648.000000
# b :-1683400832.000000
# cost :47750462334267431084621824.000000
# After 65 iteration :
# w : 804409966592.000000
# b :12352832512.000000
# cost :2735185222145132768482295808.000000
# After 66 iteration :
# w : -6205240508416.000000
# b :-93853999104.000000
# cost :167804702828551493373539647488.000000
# After 67 iteration :
# w : 49517986578432.000000
# b :737836007424.000000
# cost :11012065396317609869635791880192.000000
# After 68 iteration :
# w : -408524773392384.000000
# b :-5998086455296.000000
# cost :772044168236668255882724526522368.000000
# After 69 iteration :
# w : 3482276000169984.000000
# b :50390330507264.000000
# cost :57757276003536973548961444233478144.000000
# After 70 iteration :
# w : -30651085647511552.000000
# b :-437229113573376.000000
# cost :4605372729153257073293420500076199936.000000
# After 71 iteration :
# w : 278435273736454144.000000
# b :3916099640885248.000000
# cost :inf
# After 72 iteration :
# w : -2608945654520610816.000000
# b :-36186418023759872.000000
# cost :inf
# After 73 iteration :
# w : 25202484363369906176.000000
# b :344792071783055360.000000
# cost :inf
# After 74 iteration :
# w : -250866173882302201856.000000
# b :-3385865518509457408.000000
# cost :inf
# After 75 iteration :
# w : 2571886120326188236800.000000
# b :34250836139315298304.000000
# cost :inf
# After 76 iteration :
# w : -27143748896916145963008.000000
# b :-356744376154712965120.000000
# cost :inf
# After 77 iteration :
# w : 294781762529647604531200.000000
# b :3824106367217020436480.000000
# cost :inf
# After 78 iteration :
# w : -3292719029344805916246016.000000
# b :-42169495643280285630464.000000
# cost :inf
# After 79 iteration :
# w : 37813664776204947581566976.000000
# b :478164466260494663024640.000000
# cost :inf
# After 80 iteration :
# w : -446277762837141934210809856.000000
# b :-5572978133910521630425088.000000
# cost :inf
# After 81 iteration :
# w : 5410682093130034656286081024.000000
# b :66735168805398574354399232.000000
# cost :inf
# After 82 iteration :
# w : -67363112833991730861938049024.000000
# b :-820750172414819836830416896.000000
# cost :inf
# After 83 iteration :
# w : 860902294726290327578494369792.000000
# b :10363169494709917681245487104.000000
# cost :inf
# After 84 iteration :
# w : -11289891056774887029533367599104.000000
# b :-134289142315794978841477251072.000000
# cost :inf
# After 85 iteration :
# w : 151871886373481205094467218964480.000000
# b :1785261105724152540537315917824.000000
# cost :inf
# After 86 iteration :
# w : -2094924148006323157627510078832640.000000
# b :-24340273084808660106957555761152.000000
# cost :inf
# After 87 iteration :
# w : 29622276011007450417894275432841216.000000
# b :340225266077496038034140974546944.000000
# cost :inf
# After 88 iteration :
# w : -inf
# b :-4873975742198073336748554049290240.000000
# cost :inf
# After 89 iteration :
# w : nan
# b :inf
# cost :nan
# After 90 iteration :
# w : nan
# b :nan
# cost :nan
# After 91 iteration :
# w : nan
# b :nan
# cost :nan
# After 92 iteration :
# w : nan
# b :nan
# cost :nan
# After 93 iteration :
# w : nan
# b :nan
# cost :nan
# After 94 iteration :
# w : nan
# b :nan
# cost :nan
# After 95 iteration :
# w : nan
# b :nan
# cost :nan
# After 96 iteration :
# w : nan
# b :nan
# cost :nan
# After 97 iteration :
# w : nan
# b :nan
# cost :nan
# After 98 iteration :
# w : nan
# b :nan
# cost :nan
# After 99 iteration :
# w : nan
# b :nan
# cost :nan
